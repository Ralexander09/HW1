# %%
import clearml
from clearml import Task, Logger

# %%
# %env CLEARML_WEB_HOST=https://app.clear.ml/
# %env CLEARML_API_HOST=https://api.clear.ml
# %env CLEARML_FILES_HOST=https://files.clear.ml
# %env CLEARML_API_ACCESS_KEY=J2L6HKES7EI0HEIVBK2NE40209ZWNG
# %env CLEARML_API_SECRET_KEY=LJO-IQS2U5Ec0oCQ-4Lwwvw6d9emEHhH4SqiiKgpvppIyffyj6EqJVqOWznHqk6QjEI
# Out:
# env: CLEARML_WEB_HOST=https://app.clear.ml/
# env: CLEARML_API_HOST=https://api.clear.ml
# env: CLEARML_FILES_HOST=https://files.clear.ml
# env: CLEARML_API_ACCESS_KEY=J2L6HKES7EI0HEIVBK2NE40209ZWNG
# env: CLEARML_API_SECRET_KEY=LJO-IQS2U5Ec0oCQ-4Lwwvw6d9emEHhH4SqiiKgpvppIyffyj6EqJVqOWznHqk6QjEI

# %%
task.close()

# %%
# model_manager.py
import json
import os
import subprocess
import uuid
from io import BytesIO

import joblib
import pandas as pd
from minio import Minio
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, max_error, r2_score, mean_absolute_percentage_error


class ModelManager:
    def __init__(
        self, models_dir="saved_models", data_dir="data", bucket_name="my-bucket"
    ):
        self.models = {}
        self.models_dir = models_dir
        self.data_dir = data_dir
        os.makedirs(self.models_dir, exist_ok=True)
        os.makedirs(self.data_dir, exist_ok=True)

        # Инициализируем MinIO клиент
        self.minio_client = Minio(
            "localhost:9000",
            access_key="minioadmin",
            secret_key="minioadmin123",
            secure=False,
        )

        # Проверяем наличие bucket, если нет - создаём
        found = self.minio_client.bucket_exists(bucket_name)
        if not found:
            self.minio_client.make_bucket(bucket_name)
        self.bucket_name = bucket_name

        self.model_classes = {
            "RandomForest": RandomForestRegressor,
            "LinearRegression": LinearRegression,
        }

        self.DEFAULT_DATA = [
            {"X": 230.1, "y": 22.1},
            {"X": 44.5, "y": 10.4},
            {"X": 17.2, "y": 9.3},
            {"X": 151.5, "y": 18.5},
            {"X": 180.8, "y": 12.9},
            {"X": 8.7, "y": 7.2},
            {"X": 57.5, "y": 11.8},
            {"X": 120.2, "y": 13.2},
            {"X": 8.6, "y": 4.8},
            {"X": 199.8, "y": 10.6},
            {"X": 66.1, "y": 8.6},
            {"X": 214.7, "y": 17.4},
            {"X": 23.8, "y": 9.2},
            {"X": 97.5, "y": 9.7},
            {"X": 204.1, "y": 19},
            {"X": 195.4, "y": 22.4},
            {"X": 67.8, "y": 12.5},
            {"X": 281.4, "y": 24.4},
            {"X": 69.2, "y": 11.3},
            {"X": 147.3, "y": 14.6},
            {"X": 218.4, "y": 18},
            {"X": 237.4, "y": 12.5},
            {"X": 13.2, "y": 5.6},
            {"X": 228.3, "y": 15.5},
            {"X": 62.3, "y": 9.7},
            {"X": 262.9, "y": 12},
            {"X": 142.9, "y": 15},
            {"X": 240.1, "y": 15.9},
            {"X": 248.8, "y": 18.9},
            {"X": 70.6, "y": 10.5},
            {"X": 292.9, "y": 21.4},
            {"X": 112.9, "y": 11.9},
            {"X": 97.2, "y": 9.6},
            {"X": 265.6, "y": 17.4},
            {"X": 95.7, "y": 9.5},
            {"X": 290.7, "y": 12.8},
            {"X": 266.9, "y": 25.4},
            {"X": 74.7, "y": 14.7},
            {"X": 43.1, "y": 10.1},
            {"X": 228, "y": 21.5},
            {"X": 202.5, "y": 16.6},
            {"X": 177, "y": 17.1},
            {"X": 293.6, "y": 20.7},
            {"X": 206.9, "y": 12.9},
            {"X": 25.1, "y": 8.5},
            {"X": 175.1, "y": 14.9},
            {"X": 89.7, "y": 10.6},
            {"X": 239.9, "y": 23.2},
            {"X": 227.2, "y": 14.8},
            {"X": 66.9, "y": 9.7},
            {"X": 199.8, "y": 11.4},
            {"X": 100.4, "y": 10.7},
            {"X": 216.4, "y": 22.6},
            {"X": 182.6, "y": 21.2},
            {"X": 262.7, "y": 20.2},
            {"X": 198.9, "y": 23.7},
            {"X": 7.3, "y": 5.5},
            {"X": 136.2, "y": 13.2},
            {"X": 210.8, "y": 23.8},
            {"X": 210.7, "y": 18.4},
            {"X": 53.5, "y": 8.1},
            {"X": 261.3, "y": 24.2},
            {"X": 239.3, "y": 15.7},
            {"X": 102.7, "y": 14},
            {"X": 131.1, "y": 18},
            {"X": 69, "y": 9.3},
            {"X": 31.5, "y": 9.5},
            {"X": 139.3, "y": 13.4},
            {"X": 237.4, "y": 18.9},
            {"X": 216.8, "y": 22.3},
            {"X": 199.1, "y": 18.3},
            {"X": 109.8, "y": 12.4},
            {"X": 26.8, "y": 8.8},
            {"X": 129.4, "y": 11},
            {"X": 213.4, "y": 17},
            {"X": 16.9, "y": 8.7},
            {"X": 27.5, "y": 6.9},
            {"X": 120.5, "y": 14.2},
            {"X": 5.4, "y": 5.3},
            {"X": 116, "y": 11},
            {"X": 76.4, "y": 11.8},
            {"X": 239.8, "y": 12.3},
            {"X": 75.3, "y": 11.3},
            {"X": 68.4, "y": 13.6},
            {"X": 213.5, "y": 21.7},
            {"X": 193.2, "y": 15.2},
            {"X": 76.3, "y": 12},
            {"X": 110.7, "y": 16},
            {"X": 88.3, "y": 12.9},
            {"X": 109.8, "y": 16.7},
            {"X": 134.3, "y": 11.2},
            {"X": 28.6, "y": 7.3},
            {"X": 217.7, "y": 19.4},
            {"X": 250.9, "y": 22.2},
            {"X": 107.4, "y": 11.5},
            {"X": 163.3, "y": 16.9},
            {"X": 197.6, "y": 11.7},
            {"X": 184.9, "y": 15.5},
            {"X": 289.7, "y": 25.4},
            {"X": 135.2, "y": 17.2},
            {"X": 222.4, "y": 11.7},
            {"X": 296.4, "y": 23.8},
            {"X": 280.2, "y": 14.8},
            {"X": 187.9, "y": 14.7},
            {"X": 238.2, "y": 20.7},
            {"X": 137.9, "y": 19.2},
            {"X": 25, "y": 7.2},
            {"X": 90.4, "y": 8.7},
            {"X": 13.1, "y": 5.3},
            {"X": 255.4, "y": 19.8},
            {"X": 225.8, "y": 13.4},
            {"X": 241.7, "y": 21.8},
            {"X": 175.7, "y": 14.1},
            {"X": 209.6, "y": 15.9},
            {"X": 78.2, "y": 14.6},
            {"X": 75.1, "y": 12.6},
            {"X": 139.2, "y": 12.2},
            {"X": 76.4, "y": 9.4},
            {"X": 125.7, "y": 15.9},
            {"X": 19.4, "y": 6.6},
            {"X": 141.3, "y": 15.5},
            {"X": 18.8, "y": 7},
            {"X": 224, "y": 11.6},
            {"X": 123.1, "y": 15.2},
            {"X": 229.5, "y": 19.7},
            {"X": 87.2, "y": 10.6},
            {"X": 7.8, "y": 6.6},
            {"X": 80.2, "y": 8.8},
            {"X": 220.3, "y": 24.7},
            {"X": 59.6, "y": 9.7},
            {"X": 0.7, "y": 1.6},
            {"X": 265.2, "y": 12.7},
            {"X": 8.4, "y": 5.7},
            {"X": 219.8, "y": 19.6},
            {"X": 36.9, "y": 10.8},
            {"X": 48.3, "y": 11.6},
            {"X": 25.6, "y": 9.5},
            {"X": 273.7, "y": 20.8},
            {"X": 43, "y": 9.6},
            {"X": 184.9, "y": 20.7},
            {"X": 73.4, "y": 10.9},
            {"X": 193.7, "y": 19.2},
            {"X": 220.5, "y": 20.1},
            {"X": 104.6, "y": 10.4},
            {"X": 96.2, "y": 11.4},
            {"X": 140.3, "y": 10.3},
            {"X": 240.1, "y": 13.2},
            {"X": 243.2, "y": 25.4},
            {"X": 38, "y": 10.9},
            {"X": 44.7, "y": 10.1},
            {"X": 280.7, "y": 16.1},
            {"X": 121, "y": 11.6},
            {"X": 197.6, "y": 16.6},
            {"X": 171.3, "y": 19},
            {"X": 187.8, "y": 15.6},
            {"X": 4.1, "y": 3.2},
            {"X": 93.9, "y": 15.3},
            {"X": 149.8, "y": 10.1},
            {"X": 11.7, "y": 7.3},
            {"X": 131.7, "y": 12.9},
            {"X": 172.5, "y": 14.4},
            {"X": 85.7, "y": 13.3},
            {"X": 188.4, "y": 14.9},
            {"X": 163.5, "y": 18},
            {"X": 117.2, "y": 11.9},
            {"X": 234.5, "y": 11.9},
            {"X": 17.9, "y": 8},
            {"X": 206.8, "y": 12.2},
            {"X": 215.4, "y": 17.1},
            {"X": 284.3, "y": 15},
            {"X": 50, "y": 8.4},
            {"X": 164.5, "y": 14.5},
            {"X": 19.6, "y": 7.6},
            {"X": 168.4, "y": 11.7},
            {"X": 222.4, "y": 11.5},
            {"X": 276.9, "y": 27},
            {"X": 248.4, "y": 20.2},
            {"X": 170.2, "y": 11.7},
            {"X": 276.7, "y": 11.8},
            {"X": 165.6, "y": 12.6},
            {"X": 156.6, "y": 10.5},
            {"X": 218.5, "y": 12.2},
            {"X": 56.2, "y": 8.7},
            {"X": 287.6, "y": 26.2},
            {"X": 253.8, "y": 17.6},
            {"X": 205, "y": 22.6},
            {"X": 139.5, "y": 10.3},
            {"X": 191.1, "y": 17.3},
            {"X": 286, "y": 15.9},
            {"X": 18.7, "y": 6.7},
            {"X": 39.5, "y": 10.8},
            {"X": 75.5, "y": 9.9},
            {"X": 17.2, "y": 5.9},
            {"X": 166.8, "y": 19.6},
            {"X": 149.7, "y": 17.3},
            {"X": 38.2, "y": 7.6},
            {"X": 94.2, "y": 9.7},
            {"X": 177, "y": 12.8},
            {"X": 283.6, "y": 25.5},
            {"X": 232.1, "y": 13.4},
        ]

    def get_available_models(self):
        return list(self.model_classes.keys())

    def train_model(self, model_type, hyperparams, data=None):
        if model_type not in self.model_classes:
            raise ValueError(f"Model type '{model_type}' is not supported.")

        # Создаём уникальный ID модели
        model_id = str(uuid.uuid4())
        
        # Инициализируем задачу ClearML
        task = Task.init(
                    project_name='MLOps_HW2', 
                    task_name='Model' + ' ' + model_id, 
                    tags=[model_type])

        # Определяем пути для данных
        data_path = os.path.join(self.data_dir, f"train_{model_id}.json")
        
        # Загружаем путь к данным в задачу ClearML
        task.upload_artifact(name='data_train.path', artifact_object=data_path)
        
        # Загружаем гиперпараметры в задачу ClearML
        task.connect(hyperparams)

        # Сохраняем датасет
        with open(data_path, "w") as f:
            json.dump(data if data is not None else self.DEFAULT_DATA, f)

        try:
            # Добавляем датасет под контроль DVC
            subprocess.run(
                ["dvc", "add", data_path],
                check=True,
                stdout=subprocess.PIPE,
                stderr=subprocess.PIPE,
            )

            # Добавляем только .dvc файл и .gitignore в Git
            subprocess.run(
                ["git", "add", f"{data_path}.dvc", ".gitignore"],
                check=True,
                stdout=subprocess.PIPE,
                stderr=subprocess.PIPE,
            )

            # Коммитим изменения
            subprocess.run(
                ["git", "commit", "-m", f"Add training dataset for model {model_id}"],
                check=True,
                stdout=subprocess.PIPE,
                stderr=subprocess.PIPE,
            )

            # Пушим датасет в удалённое хранилище
            subprocess.run(
                ["dvc", "push"],
                check=True,
                stdout=subprocess.PIPE,
                stderr=subprocess.PIPE,
            )
        except subprocess.CalledProcessError as e:
            error_message = e.stderr.decode().strip()
            raise RuntimeError(f"Ошибка при выполнении команд DVC/Git: {error_message}")

        # Загружаем данные
        df = pd.read_json(data_path)
        if df.shape[1] < 2:
            raise ValueError(
                "Data must contain at least two columns (features and target)."
            )
            
        # Загружаем сами данные в задачу ClearML
        task.upload_artifact(name='data_train.data', artifact_object=df)
        
        X = df.iloc[:, :-1]
        y = df.iloc[:, -1]

        ModelClass = self.model_classes[model_type]
        model = ModelClass(**hyperparams)
        model.fit(X, y)
        
        prediction = model.predict(X)
        mse = round(mean_squared_error(y, prediction), 3) if y is not None else None
        max_err = round(max_error(y, prediction), 3) if y is not None else None
        r2 = round(r2_score(y, prediction), 3) if y is not None else None
        mape = round(mean_absolute_percentage_error(y, prediction), 3) if y is not None else None
        
        # Логируем метрики на обучении в ClearML
        log = Logger.current_logger()
        log.report_single_value(name='Train MSE', value=mse)
        log.report_single_value(name='Train Maximum Error', value=max_err)
        log.report_single_value(name='Train Determination coef.', value=r2)
        log.report_single_value(name='Train MAPE', value=mape)
        log.report_single_value(name='Train Rows', value=X.shape[0])
        log.report_single_value(name='Train Ratio', value=round(y.mean(),3))

        self.models[model_id] = model

        # Сохраняем модель локально
        model_path = os.path.join(self.models_dir, f"{model_id}.joblib")
        joblib.dump(model, model_path)
        
        # Сохраняем модель в ClearML
        model.save_model(f"{model_id}.cbm")

        # Загружаем модель в MinIO
        try:
            self.minio_client.fput_object(
                self.bucket_name, f"{model_id}.joblib", model_path
            )
        except Exception as e:
            os.remove(model_path)
            raise RuntimeError(f"Ошибка при загрузке модели в MinIO: {str(e)}")

        # Удаляем локальную копию модели
        os.remove(model_path)

        return model_id

    def load_model(self, model_id):
        if model_id in self.models:
            return self.models[model_id]
        # Попытаемся загрузить из MinIO
        try:
            response = self.minio_client.get_object(
                self.bucket_name, f"{model_id}.joblib"
            )
            model_bytes = response.read()
            model = joblib.load(BytesIO(model_bytes))
            self.models[model_id] = model
            return model
        except Exception:
            return None

    def predict(self, model_id, data=None):
        model = self.load_model(model_id)
        if not model:
            raise KeyError("Model not found")
                
        # Загружаем задачу в ClearML для выбранного ID модели         
        task = Task.get_task(project_name='MLOps_HW2', task_name='Model' + ' ' + model_id)

        # Загружаем данные
        if data is not None:
            df = pd.DataFrame(data)
        else:
            # Можно взять дефолтный датасет
            df = pd.DataFrame(self.DEFAULT_DATA)

        if df.empty:
            raise ValueError("No data provided for prediction.")
            
        # Загружаем сами данные в задачу ClearML
        task.upload_artifact(name='data_test.data', artifact_object=df)

        has_y = "y" in df.columns
        if has_y:
            X = df.drop(columns=["y"])
            y_true = df["y"]
        else:
            X = df
            y_true = None

        prediction = model.predict(X)
        mse = mean_squared_error(y_true, prediction) if y_true is not None else None
        max_err = round(max_error(y, prediction), 3) if y is not None else None
        r2 = round(r2_score(y, prediction), 3) if y is not None else None
        mape = round(mean_absolute_percentage_error(y, prediction), 3) if y is not None else None
        
        # Логируем метрики на обучении в ClearML
        log = Logger.current_logger()
        log.report_single_value(name='Train MSE', value=mse)
        log.report_single_value(name='Train Maximum Error', value=max_err)
        log.report_single_value(name='Train Determination coef.', value=r2)
        log.report_single_value(name='Train MAPE', value=mape)
        log.report_single_value(name='Train Rows', value=X.shape[0])
        log.report_single_value(name='Train Ratio', value=round(y.mean(),3))

        return prediction.tolist(), mse

    def delete_model(self, model_id):
        # Удаляем модель из памяти, если она загружена
        if model_id in self.models:
            del self.models[model_id]
        # Удаляем модель из MinIO
        try:
            self.minio_client.remove_object(self.bucket_name, f"{model_id}.joblib")
            return True
        except Exception:
            return False

    def list_models(self):
        # Получаем список объектов в bucket и фильтруем модели
        objects = self.minio_client.list_objects(self.bucket_name, recursive=True)
        model_ids = [
            obj.object_name.replace(".joblib", "")
            for obj in objects
            if obj.object_name.endswith(".joblib")
        ]
        return model_ids
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 10
#       8 import joblib
#       9 import pandas as pd
# ---> 10 from minio import Minio
#      11 from sklearn.ensemble import RandomForestRegressor
#      12 from sklearn.linear_model import LinearRegression
#
# ModuleNotFoundError: No module named 'minio'

# %%
Task.get_task(task_id='123456deadbeef')
# Out:
# ---------------------------------------------------------------------------
# LoginError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 Task.get_task(task_id='123456deadbeef')
#
# File C:\Users\Public\anaconda3\Lib\site-packages\clearml\task.py:1153, in Task.get_task(cls, task_id, project_name, task_name, tags, allow_archived, task_filter)
#    1072 @classmethod
#    1073 def get_task(
#    1074         cls,
#    (...)
#    1081 ):
#    1082     # type: (...) -> TaskInstance
#    1083     """
#    1084     Get a Task by ID, or project name / task name combination.
#    1085
#    (...)
#    1151     :rtype: Task
#    1152     """
# -> 1153     return cls.__get_task(
#    1154         task_id=task_id, project_name=project_name, task_name=task_name, tags=tags,
#    1155         include_archived=allow_archived, task_filter=task_filter,
#    1156     )
#
# File C:\Users\Public\anaconda3\Lib\site-packages\clearml\task.py:4624, in Task.__get_task(cls, task_id, project_name, task_name, include_archived, tags, task_filter)
#    4611 @classmethod
#    4612 def __get_task(
#    4613         cls,
#    (...)
#    4620 ):
#    4621     # type: (...) -> TaskInstance
#    4623     if task_id:
# -> 4624         return cls(private=cls.__create_protection, task_id=task_id, log_to_backend=False)
#    4626     if project_name:
#    4627         res = cls._send(
#    4628             cls._get_default_session(),
#    4629             projects.GetAllRequest(
#    4630                 name=exact_match_regex(project_name)
#    4631             )
#    4632         )
#
# File C:\Users\Public\anaconda3\Lib\site-packages\clearml\task.py:211, in Task.__init__(self, private, **kwargs)
#     207     raise UsageError(
#     208         'Task object cannot be instantiated externally, use Task.current_task() or Task.get_task(...)')
#     209 self._repo_detect_lock = threading.RLock()
# --> 211 super(Task, self).__init__(**kwargs)
#     212 self._arguments = _Arguments(self)
#     213 self._logger = None
#
# File C:\Users\Public\anaconda3\Lib\site-packages\clearml\backend_interface\task\task.py:167, in Task.__init__(self, session, task_id, log, project_name, task_name, task_type, log_to_backend, raise_on_validation_errors, force_create)
#     165 task_id = self._resolve_task_id(task_id, log=log) if not force_create else None
#     166 self.__edit_lock = None
# --> 167 super(Task, self).__init__(id=task_id, session=session, log=log)
#     168 self._project_name = None
#     169 self._storage_uri = None
#
# File C:\Users\Public\anaconda3\Lib\site-packages\clearml\backend_interface\base.py:149, in IdObjectBase.__init__(self, id, session, log, **kwargs)
#     148 def __init__(self, id, session=None, log=None, **kwargs):
# --> 149     super(IdObjectBase, self).__init__(session, log, **kwargs)
#     150     self._data = None
#     151     self._id = None
#
# File C:\Users\Public\anaconda3\Lib\site-packages\clearml\backend_interface\base.py:41, in InterfaceBase.__init__(self, session, log, **kwargs)
#      39 def __init__(self, session=None, log=None, **kwargs):
#      40     super(InterfaceBase, self).__init__()
# ---> 41     self._session = session or self._get_default_session()
#      42     self._log = log or self._create_log()
#
# File C:\Users\Public\anaconda3\Lib\site-packages\clearml\backend_interface\base.py:119, in InterfaceBase._get_default_session(cls)
#     116 @classmethod
#     117 def _get_default_session(cls):
#     118     if not InterfaceBase._default_session:
# --> 119         InterfaceBase._default_session = Session(
#     120             initialize_logging=False,
#     121             config=config_obj,
#     122             api_key=ENV_ACCESS_KEY.get(),
#     123             secret_key=ENV_SECRET_KEY.get(),
#     124         )
#     125     return InterfaceBase._default_session
#
# File C:\Users\Public\anaconda3\Lib\site-packages\clearml\backend_api\session\session.py:161, in Session.__init__(self, worker, api_key, secret_key, host, logger, verbose, config, http_retries_config, **kwargs)
#     158     from clearml.config import ConfigWrapper
#     159     self.config = ConfigWrapper._init()
# --> 161 self._connect()
#
# File C:\Users\Public\anaconda3\Lib\site-packages\clearml\backend_api\session\session.py:231, in Session._connect(self)
#     224     raise MissingConfigError()
#     226 super(Session, self).__init__(
#     227     **self.__token_manager_kwargs,
#     228     token_expiration_threshold_sec=token_expiration_threshold_sec,
#     229     req_token_expiration_sec=req_token_expiration_sec
#     230 )
# --> 231 self.refresh_token()
#     233 local_logger = self._LocalLogger(self._logger)
#     235 # update api version from server response
#
# File C:\Users\Public\anaconda3\Lib\site-packages\clearml\backend_api\session\token_manager.py:112, in TokenManager.refresh_token(self)
#     111 def refresh_token(self):
# --> 112     self._set_token(self._do_refresh_token(self.__token, exp=self.req_token_expiration_sec))
#
# File C:\Users\Public\anaconda3\Lib\site-packages\clearml\backend_api\session\session.py:883, in Session._do_refresh_token(self, old_token, exp)
#     881     return resp["data"]["token"]
#     882 except LoginError:
# --> 883     six.reraise(*sys.exc_info())
#     884 except KeyError as ex:
#     885     # check if this is a misconfigured api server (getting 200 without the data section)
#     886     if res and res.status_code == 200:
#
# File C:\Users\Public\anaconda3\Lib\site-packages\six.py:719, in reraise(tp, value, tb)
#     717     if value.__traceback__ is not tb:
#     718         raise value.with_traceback(tb)
# --> 719     raise value
#     720 finally:
#     721     value = None
#
# File C:\Users\Public\anaconda3\Lib\site-packages\clearml\backend_api\session\session.py:869, in Session._do_refresh_token(self, old_token, exp)
#     867 if res.status_code != 200:
#     868     msg = resp.get("meta", {}).get("result_msg", res.reason)
# --> 869     raise LoginError(
#     870         "Failed getting token (error {} from {}): {}".format(
#     871             res.status_code, self.host, msg
#     872         )
#     873     )
#     874 if verbose:
#     875     self._logger.info("Received new token")
#
# LoginError: Failed getting token (error 401 from https://api.clear.ml): Unauthorized (invalid credentials) (failed to locate provided credentials)
